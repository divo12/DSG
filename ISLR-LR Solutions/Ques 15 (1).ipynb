# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import statsmodels.api as sm
from patsy import dmatrices
import random as rn
import seaborn as seabornInstance

# %%
dataset=pd.read_csv(r'C:\Users\divyansh\Downloads\Boston.csv')

# %%
print(dataset)
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#15a

# %%
y,x=dmatrices('crim~zn',data=dataset)

# %%
mod1=sm.OLS(y,x)
res1=mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     21.10
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           5.51e-06
# Time:                        18:20:06   Log-Likelihood:                -1796.0
# No. Observations:                 506   AIC:                             3596.
# Df Residuals:                     504   BIC:                             3604.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.4537      0.417     10.675      0.000       3.634       5.273
# ...

# %%
y,x=dmatrices('crim~indus',data=dataset)
mod2=sm.OLS(y,x)
res2=mod2.fit()
print(res2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     99.82
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           1.45e-21
# Time:                        18:20:06   Log-Likelihood:                -1760.6
# No. Observations:                 506   AIC:                             3525.
# Df Residuals:                     504   BIC:                             3534.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.0637      0.667     -3.093      0.002      -3.375      -0.753
# ...

# %%
y,x=dmatrices('crim~chas',data=dataset)
mod3=sm.OLS(y,x)
res3=mod3.fit()
print(res3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.579
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):              0.209
# Time:                        18:20:06   Log-Likelihood:                -1805.6
# No. Observations:                 506   AIC:                             3615.
# Df Residuals:                     504   BIC:                             3624.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.7444      0.396      9.453      0.000       2.966       4.523
# ...

# %%
y,x=dmatrices('crim~nox',data=dataset)
mod4=sm.OLS(y,x)
res4=mod4.fit()
print(res4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.176
# Method:                 Least Squares   F-statistic:                     108.6
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           3.75e-23
# Time:                        18:20:06   Log-Likelihood:                -1757.0
# No. Observations:                 506   AIC:                             3518.
# Df Residuals:                     504   BIC:                             3526.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -13.7199      1.699     -8.073      0.000     -17.059     -10.381
# ...

# %%
y,x=dmatrices('crim~rm',data=dataset)
mod5=sm.OLS(y,x)
res5=mod5.fit()
print(res5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     25.45
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           6.35e-07
# Time:                        18:20:06   Log-Likelihood:                -1793.9
# No. Observations:                 506   AIC:                             3592.
# Df Residuals:                     504   BIC:                             3600.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     20.4818      3.364      6.088      0.000      13.872      27.092
# ...

# %%
y,x=dmatrices('crim~age',data=dataset)
mod6=sm.OLS(y,x)
res6=mod6.fit()
print(res6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.124
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     71.62
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           2.85e-16
# Time:                        18:20:06   Log-Likelihood:                -1772.7
# No. Observations:                 506   AIC:                             3549.
# Df Residuals:                     504   BIC:                             3558.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.7779      0.944     -4.002      0.000      -5.633      -1.923
# ...

# %%
y,x=dmatrices('crim~rad',data=dataset)
mod7=sm.OLS(y,x)
res7=mod7.fit()
print(res7.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.390
# Method:                 Least Squares   F-statistic:                     323.9
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           2.69e-56
# Time:                        18:20:06   Log-Likelihood:                -1680.8
# No. Observations:                 506   AIC:                             3366.
# Df Residuals:                     504   BIC:                             3374.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.2872      0.443     -5.157      0.000      -3.158      -1.416
# ...

# %%
y,x=dmatrices('crim~tax',data=dataset)
mod8=sm.OLS(y,x)
res8=mod8.fit()
print(res8.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.340
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     259.2
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           2.36e-47
# Time:                        18:20:06   Log-Likelihood:                -1701.4
# No. Observations:                 506   AIC:                             3407.
# Df Residuals:                     504   BIC:                             3415.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -8.5284      0.816    -10.454      0.000     -10.131      -6.926
# ...

# %%
y,x=dmatrices('crim~ptratio',data=dataset)
mod9=sm.OLS(y,x)
res9=mod9.fit()
print(res9.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     46.26
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           2.94e-11
# Time:                        18:20:06   Log-Likelihood:                -1784.1
# No. Observations:                 506   AIC:                             3572.
# Df Residuals:                     504   BIC:                             3581.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -17.6469      3.147     -5.607      0.000     -23.830     -11.464
# ...

# %%
y,x=dmatrices('crim~black',data=dataset)
mod10=sm.OLS(y,x)
res10=mod10.fit()
print(res10.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.147
# Method:                 Least Squares   F-statistic:                     87.74
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           2.49e-19
# Time:                        18:20:06   Log-Likelihood:                -1765.8
# No. Observations:                 506   AIC:                             3536.
# Df Residuals:                     504   BIC:                             3544.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     16.5535      1.426     11.609      0.000      13.752      19.355
# ...

# %%
y,x=dmatrices('crim~lstat',data=dataset)
mod11=sm.OLS(y,x)
res11=mod11.fit()
print(res11.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     132.0
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           2.65e-27
# Time:                        18:20:06   Log-Likelihood:                -1747.5
# No. Observations:                 506   AIC:                             3499.
# Df Residuals:                     504   BIC:                             3507.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.3305      0.694     -4.801      0.000      -4.694      -1.968
# ...

# %%
y,x=dmatrices('crim~medv',data=dataset)
mod12=sm.OLS(y,x)
res12=mod12.fit()
print(res12.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     89.49
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           1.17e-19
# Time:                        18:20:07   Log-Likelihood:                -1765.0
# No. Observations:                 506   AIC:                             3534.
# Df Residuals:                     504   BIC:                             3542.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.7965      0.934     12.628      0.000       9.961      13.632
# ...

# %%
y,x=dmatrices('crim~dis',data=dataset)
mod13=sm.OLS(y,x)
res13=mod13.fit()
print(res13.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.144
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     84.89
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           8.52e-19
# Time:                        18:20:07   Log-Likelihood:                -1767.0
# No. Observations:                 506   AIC:                             3538.
# Df Residuals:                     504   BIC:                             3546.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.4993      0.730     13.006      0.000       8.064      10.934
# ...

# %%
#15b
y,x=dmatrices('crim~zn+indus+chas+nox+rm+age+dis+rad+tax+ptratio+black+lstat+medv',data=dataset)
mod_all = sm.OLS(y,x)
res_all = mod_all.fit()
print(res_all.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     31.47
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           1.57e-56
# Time:                        18:20:07   Log-Likelihood:                -1653.3
# No. Observations:                 506   AIC:                             3335.
# Df Residuals:                     492   BIC:                             3394.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     17.0332      7.235      2.354      0.019       2.818      31.248
# ...

# %%
t=np.array(res_all.params)
t=np.delete(t,0,0)
print(t)
# Out:
# [ 4.48552147e-02 -6.38548236e-02 -7.49133611e-01 -1.03135349e+01
#   4.30130506e-01  1.45164344e-03 -9.87175726e-01  5.88208591e-01
#  -3.78001638e-03 -2.71080558e-01 -7.53750489e-03  1.26211376e-01
#  -1.98886821e-01]

# %%
k=np.array([-0.0739,0.5098,-1.8928,31.2485,-2.6841,0.1078,-1.5509,0.6179,0.0297,1.1520,-0.0363,0.5488,-0.3632])

# %%
#15c
plt.scatter(k,t)
plt.xlabel("univariate coefficients")
plt.ylabel("multi-variate coefficients")
# Out:
# Text(0, 0.5, 'multi-variate coefficients')

# %%
#15d
import statsmodels.formula.api as smf

# %%
dataset["zn2"]=dataset.zn**2
dataset["zn3"]=dataset.zn**3
y,x=dmatrices('dataset.crim~dataset.zn+dataset.zn2+dataset.zn3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     10.35
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           1.28e-06
# Time:                        18:21:17   Log-Likelihood:                -1791.2
# No. Observations:                 506   AIC:                             3590.
# Df Residuals:                     502   BIC:                             3607.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       4.8461      0.433     11.192      0.000       3.995       5.697
# ...

# %%
dataset["indus2"]=dataset.indus**2
dataset["indus3"]=dataset.indus**3
y,x=dmatrices('dataset.crim~dataset.indus+dataset.indus2+dataset.indus3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.260
# Model:                            OLS   Adj. R-squared:                  0.255
# Method:                 Least Squares   F-statistic:                     58.69
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           1.55e-32
# Time:                        18:22:37   Log-Likelihood:                -1730.3
# No. Observations:                 506   AIC:                             3469.
# Df Residuals:                     502   BIC:                             3486.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
dataset["chas2"]=dataset.chas**2
dataset["chas3"]=dataset.chas**3
y,x=dmatrices('dataset.crim~dataset.chas+dataset.chas2+dataset.chas3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.579
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):              0.209
# Time:                        18:23:52   Log-Likelihood:                -1805.6
# No. Observations:                 506   AIC:                             3615.
# Df Residuals:                     504   BIC:                             3624.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
dataset["nox2"]=dataset.nox**2
dataset["nox3"]=dataset.nox**3
y,x=dmatrices('dataset.crim~dataset.nox+dataset.nox2+dataset.nox3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.297
# Model:                            OLS   Adj. R-squared:                  0.293
# Method:                 Least Squares   F-statistic:                     70.69
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           3.81e-38
# Time:                        18:25:54   Log-Likelihood:                -1717.2
# No. Observations:                 506   AIC:                             3442.
# Df Residuals:                     502   BIC:                             3459.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
dataset["rm2"]=dataset.rm**2
dataset["rm3"]=dataset.rm**3
y,x=dmatrices('dataset.crim~dataset.rm+dataset.rm2+dataset.rm3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     12.17
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           1.07e-07
# Time:                        18:26:40   Log-Likelihood:                -1788.6
# No. Observations:                 506   AIC:                             3585.
# Df Residuals:                     502   BIC:                             3602.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     112.6246     64.517      1.746      0.081     -14.132     239.382
# ...

# %%
dataset["age2"]=dataset.age**2
dataset["age3"]=dataset.age**3
y,x=dmatrices('dataset.crim~dataset.age+dataset.age2+dataset.age3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                  0.169
# Method:                 Least Squares   F-statistic:                     35.31
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           1.02e-20
# Time:                        18:27:37   Log-Likelihood:                -1757.9
# No. Observations:                 506   AIC:                             3524.
# Df Residuals:                     502   BIC:                             3541.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
dataset["dis2"]=dataset.dis**2
dataset["dis3"]=dataset.dis**3
y,x=dmatrices('dataset.crim~dataset.dis+dataset.dis2+dataset.dis3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.278
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     64.37
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           3.14e-35
# Time:                        18:28:30   Log-Likelihood:                -1724.0
# No. Observations:                 506   AIC:                             3456.
# Df Residuals:                     502   BIC:                             3473.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
dataset["rad2"]=dataset.rad**2
dataset["rad3"]=dataset.rad**3
y,x=dmatrices('dataset.crim~dataset.rad+dataset.rad2+dataset.rad3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.400
# Model:                            OLS   Adj. R-squared:                  0.396
# Method:                 Least Squares   F-statistic:                     111.6
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           2.31e-55
# Time:                        18:29:09   Log-Likelihood:                -1677.1
# No. Observations:                 506   AIC:                             3362.
# Df Residuals:                     502   BIC:                             3379.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
dataset["tax2"]=dataset.tax**2
dataset["tax3"]=dataset.tax**3
y,x=dmatrices('dataset.crim~dataset.tax+dataset.tax2+dataset.tax3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.369
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     97.80
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           7.34e-50
# Time:                        18:29:49   Log-Likelihood:                -1689.9
# No. Observations:                 506   AIC:                             3388.
# Df Residuals:                     502   BIC:                             3405.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
dataset["ptratio2"]=dataset.ptratio**2
dataset["ptratio3"]=dataset.ptratio**3
y,x=dmatrices('dataset.crim~dataset.ptratio+dataset.ptratio2+dataset.ptratio3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.114
# Model:                            OLS   Adj. R-squared:                  0.108
# Method:                 Least Squares   F-statistic:                     21.48
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           4.17e-13
# Time:                        18:30:34   Log-Likelihood:                -1775.8
# No. Observations:                 506   AIC:                             3560.
# Df Residuals:                     502   BIC:                             3577.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
dataset["black2"]=dataset.black**2
dataset["black3"]=dataset.black**3
y,x=dmatrices('dataset.crim~dataset.black+dataset.black2+dataset.black3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     29.49
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           1.41e-17
# Time:                        18:33:38   Log-Likelihood:                -1765.3
# No. Observations:                 506   AIC:                             3539.
# Df Residuals:                     502   BIC:                             3555.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
dataset["lstat2"]=dataset.lstat**2
dataset["lstat3"]=dataset.lstat**3
y,x=dmatrices('dataset.crim~dataset.lstat+dataset.lstat2+dataset.lstat3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.213
# Method:                 Least Squares   F-statistic:                     46.63
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           1.35e-26
# Time:                        18:36:08   Log-Likelihood:                -1744.2
# No. Observations:                 506   AIC:                             3496.
# Df Residuals:                     502   BIC:                             3513.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
dataset["medv2"]=dataset.medv**2
dataset["medv3"]=dataset.medv**3
y,x=dmatrices('dataset.crim~dataset.medv+dataset.medv2+dataset.medv3')

model2= sm.OLS(y,x)
result2=model2.fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           dataset.crim   R-squared:                       0.420
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     121.3
# Date:                Sun, 11 Apr 2021   Prob (F-statistic):           4.45e-59
# Time:                        18:37:00   Log-Likelihood:                -1668.5
# No. Observations:                 506   AIC:                             3345.
# Df Residuals:                     502   BIC:                             3362.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...
